# %% [markdown]
# <a href="https://colab.research.google.com/github/mataweimataweev/-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Цель работы: научится анализировать датасеты и их содержимое на платформе colab

# %% [markdown]
# Был выведен дата сет с греческими богами

# %%
import pandas as pd
import numpy as np

GREEKI = pd.read_csv("greek_gods.csv")

GREEKI
# Out:
#     name-english name-greek main-type  sub-type  \
# 0      Aphrodite   Ἀφροδίτη       god  olympian
# 1         Apollo    Ἀπόλλων       god  olympian
# 2           Ares       Ἄρης       god  olympian
# 3        Artemis    Ἄρτεμις       god  olympian
# 4         Athena      Ἀθηνᾶ       god  olympian
# ..           ...        ...       ...       ...
# 440       Rhapso       Ραψώ       god     nymph
# 441    Alexiares  Αλεξιαρης       god     other
# 442     Anicetus   Ανικητος       god     other
# 443      Auxesia    Αυξησία       god     other
# 444        Damia      Δαμία       god     other
#
#                                            description
# 0        goddess of beauty, love, desire, and pleasure
# 1    god of music, arts, knowledge, healing, plague...
# 2         god of courage, war, bloodshed, and violence
# 3    virgin goddess of the hunt, wilderness, animal...
# 4    goddess of reason, wisdom, intelligence, skill...
# ...

# %% [markdown]
# Выводим размерность массива

# %%
print(GREEKI.shape)
# Out:
# (445, 5)

# %% [markdown]
# После этого была выведены рамерность масиива(445, 5)

# %%
print(GREEKI.columns)
# Out:
# Index(['name-english', 'name-greek', 'main-type', 'sub-type', 'description'], dtype='object')

# %% [markdown]
# Затем выводим количество этих данных в "уникальном ключе"

# %%
GREEKI.nunique()
# Out:
# name-english    445
# name-greek      441
# main-type         3
# sub-type         16
# description     395
# dtype: int64

# %% [markdown]
#  В ходе действий выведены уникальные значения из моего дата сеста

# %%
GREEKI.columns
# Out:
# Index(['name-english', 'name-greek', 'main-type', 'sub-type', 'description'], dtype='object')

# %% [markdown]
# Были выведены наименование всех колонок(1 колонка-имя на англиссом,2 колонка - греческое имя, 3- основной тип, 4 - под тип, 5 - описание бога)

# %%
GREEKI.nunique()
# Out:
# name-english    445
# name-greek      441
# main-type         3
# sub-type         16
# description     395
# dtype: int64

# %% [markdown]
# Вывод уникальных данных из нашего дата сета

# %%
GREEKI.sort_values(by='name-greek')
# Out:
#      name-english  name-greek        main-type         sub-type  \
# 109      Eupraxia    Eὐπραξία  personification  personification
# 110      Eusebeia    Eὐσέβεια  personification  personification
# 124         Kakia       Kακία  personification  personification
# 192       Kokytos     Kωκυτός              god         chthonic
# 40      Mnemosyne   Mνημοσύνη            titan     twelve titan
# ..            ...         ...              ...              ...
# 24         Hypnos       Ὕπνος              god       primordial
# 41        Oceanus     Ὠκεανός            titan     twelve titan
# 7           Hades        ᾍδης              god         olympian
# 43           Rhea         Ῥέα            titan     twelve titan
# 184  Rhadamanthys  Ῥαδάμανθυς              god         chthonic
#
#                                            description
# 109                               spirit of well-being
# 110  spirit of piety, loyalty, duty, and filial res...
# ...

# %% [markdown]
# Сортировка значений по уникальному столбцу

# %%
GREEKI['name-greek'].unique()
# Out:
# array(['Ἀφροδίτη', 'Ἀπόλλων', 'Ἄρης', 'Ἄρτεμις', 'Ἀθηνᾶ', 'Δημήτηρ',
#        'Διόνυσος', 'ᾍδης', 'Ἥφαιστος', 'Ἥρα', 'Ἑρμῆς', 'Ἑστία',
#        'Ποσειδῶν', 'Ζεύς', 'Ἀχλύς', 'Αἰθήρ', 'Αἰών', 'Ἀνάγκη', 'Χάος',
#        'Χρόνος', 'Ἔρεβος', 'Ἔρως', 'Γαῖα', 'Ἡμέρα', 'Ὕπνος', 'Νέμεσις',
#        'Νῆσοι', 'Νύξ', 'Οὔρεα', 'Φάνης', 'Πόντος', 'Τάρταρος', 'Θάλασσα',
#        'Θάνατος', 'Οὐρανός', 'Κοῖος', 'Κρεῖος', 'Κρόνος', 'Ὑπερίων',
#        'Ἰαπετός', 'Mνημοσύνη', 'Ὠκεανός', 'Φοίβη', 'Ῥέα', 'Τηθύς', 'Θεία',
#        'Θέμις', 'Ἀστερία', 'Ἀστραῖος', 'Ἄτλας', 'Διώνη', 'Ἥλιος',
#        'Σελήνη', 'Ἠώς', 'Ἐπιμηθεύς', 'Λήλαντος', 'Λητώ', 'Μενοίτιος',
#        'Μῆτις', 'Πάλλας', 'Πέρσης', 'Προμηθεύς', 'Στύξ', 'Ἀδηφαγία',
#        'Ἀδικία', 'Ἀεργία', 'Ἀγαθοδαίμων', 'Ἀγών', 'Αἰδώς', 'Αἴσα',
#        'Ἀλαλά', 'Ἀλάστωρ', 'Ἀλήθεια', 'Ἄχος', 'Ἀνία', 'Λύπη', 'Ἀλκή',
#        'Ἀμηχανία', 'Ἀμφιλογίαι', 'Ἀναίδεια', 'Ἀνδροκτασίαι', 'Ἀγγελία',
# ...

# %% [markdown]
# Вывод уникальных данных в виде имён греческих богов

# %%
GREEKI.drop(columns = ["sub-type"])
# Out:
#     name-english name-greek main-type  \
# 0      Aphrodite   Ἀφροδίτη       god
# 1         Apollo    Ἀπόλλων       god
# 2           Ares       Ἄρης       god
# 3        Artemis    Ἄρτεμις       god
# 4         Athena      Ἀθηνᾶ       god
# ..           ...        ...       ...
# 440       Rhapso       Ραψώ       god
# 441    Alexiares  Αλεξιαρης       god
# 442     Anicetus   Ανικητος       god
# 443      Auxesia    Αυξησία       god
# 444        Damia      Δαμία       god
#
#                                            description
# 0        goddess of beauty, love, desire, and pleasure
# 1    god of music, arts, knowledge, healing, plague...
# 2         god of courage, war, bloodshed, and violence
# 3    virgin goddess of the hunt, wilderness, animal...
# 4    goddess of reason, wisdom, intelligence, skill...
# ..                                                 ...
# 440  minor goddess or nymph whose name apparently r...
# 441  son of heracles presiding over the defence of ...
# ...

# %% [markdown]
# Удаление ненужного(по моему мнению ) столбца

# %%
GREEKI.drop_duplicates()
# Out:
#     name-english name-greek main-type  sub-type  \
# 0      Aphrodite   Ἀφροδίτη       god  olympian
# 1         Apollo    Ἀπόλλων       god  olympian
# 2           Ares       Ἄρης       god  olympian
# 3        Artemis    Ἄρτεμις       god  olympian
# 4         Athena      Ἀθηνᾶ       god  olympian
# ..           ...        ...       ...       ...
# 440       Rhapso       Ραψώ       god     nymph
# 441    Alexiares  Αλεξιαρης       god     other
# 442     Anicetus   Ανικητος       god     other
# 443      Auxesia    Αυξησία       god     other
# 444        Damia      Δαμία       god     other
#
#                                            description
# 0        goddess of beauty, love, desire, and pleasure
# 1    god of music, arts, knowledge, healing, plague...
# 2         god of courage, war, bloodshed, and violence
# 3    virgin goddess of the hunt, wilderness, animal...
# 4    goddess of reason, wisdom, intelligence, skill...
# ...

# %% [markdown]
# Удаление дубликатов из дата сета

# %%
GREEKI = GREEKI.replace(np.nan, "N/A")

# %% [markdown]
# Заменить определенные значения в датасете ( пустые)

# %%
GREEKI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445 entries, 0 to 444
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name-english  445 non-null    object
#  1   name-greek    445 non-null    object
#  2   main-type     445 non-null    object
#  3   sub-type      445 non-null    object
#  4   description   445 non-null    object
# dtypes: object(5)
# memory usage: 17.5+ KB

# %% [markdown]
# Провели анализ с помощью функций info

# %%
GREEKI.describe()
# Out:
#        name-english name-greek main-type         sub-type  \
# count           445        445       445              445
# unique          445        441         3               16
# top       Aphrodite   Ἀστραῖος       god  personification
# freq              1          2       307              110
#
#                                               description
# count                                                 445
# unique                                                395
# top     sea spirit native to the island of rhodes (tel...
# freq                                                   16

# %% [markdown]
# Провели анализ с помощью функций describe

# %%
selected_data = GREEKI.loc[0:5, ["name-english", "name-greek", "main-type"]]
print(selected_data)
# Out:
#   name-english name-greek main-type
# 0    Aphrodite   Ἀφροδίτη       god
# 1       Apollo    Ἀπόλλων       god
# 2         Ares       Ἄρης       god
# 3      Artemis    Ἄρτεμις       god
# 4       Athena      Ἀθηνᾶ       god
# 5      Demeter    Δημήτηρ       god

# %% [markdown]
# Затем с помощью loc была проведена выборка по строкам и столбцам

# %%
GREEKI.to_csv("GREEKI_otsortirovann.csv")

# %% [markdown]
# Сохранение нового дата сета

# %% [markdown]
# В ходе данной очень интересной и увлекательной работы с дата сетами был создан отсортированный новый дата сет и показана робота с его анализом
